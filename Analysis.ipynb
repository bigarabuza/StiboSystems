# %%
import pandas as pd
import pyarrow.feather as feather
from pathlib2 import Path

# %%
ice_cat_full_data = pd.read_feather(Path("IceCat Full/IceCat_Cat_2833_feather/frame_IceCat_Category_4.feather"))
ice_cat_full_data.head()
# Out:
#    level_0  index                    id  \
# 0        0      0  IceCat_Prod_13646101
# 1        1      0   IceCat_Prod_5469958
# 2        2      0  IceCat_Prod_15753191
# 3        3      0   IceCat_Prod_4783600
# 4        4      0  IceCat_Prod_13701792
#
#                                                 name        category_id  \
# 0              SQL Server Standard 2012, GOV, OLP NL  IceCat_Category_4
# 1  Small Business Server 2008 Premium, OLP-NL, 20...  IceCat_Category_4
# 2                       Access 2013, x32/64, 1u, ENG  IceCat_Category_4
# 3  SQL Server 2008 R2 Standard, EDU, 10u, CAL, DV...  IceCat_Category_4
# 4                          SQL Server Developer 2012  IceCat_Category_4
#
#       category_label License quantity.1558 License quantity.1558.unit  \
# 0  Database Software                     1                 license(s)
# 1  Database Software                    20                 license(s)
# 2  Database Software                     1                 license(s)
# ...
