# %%
import os
import pyarrow.feather as feather
import pandas as pd

# %%
path = "/Users/wshabana/Documents/Stibo-DG/StiboSystems/IceCat_Full/IceCat_Cat_2833_feather/"
os.chdir(path)

# %%
files_feather = [f"{path}/{file}" for file in os.listdir()]

# %%
files_df = [feather.read_feather(i) for i in files_feather]

# %%
len(files_df)
# Out:
# 495

# %%
files_df[4]
# Out:
#      level_0  index                    id            name  \
# 0          0      0  IceCat_Prod_44544241    BEX60134WP3F
# 1          1      0  IceCat_Prod_44544329  CBX30068FS1PCY
# 2          2      0  IceCat_Prod_44544333  CBX30109AS1SGR
# 3          3      0  IceCat_Prod_44544289    BSA45060SG3F
# 4          4      0  IceCat_Prod_44544246    BEX60152RS2E
# ..       ...    ...                   ...             ...
# 137      140      0  IceCat_Prod_44544218    BEX60060AW1F
# 138      141      0  IceCat_Prod_37116587    BFV30083SS3F
# 139      142      0  IceCat_Prod_44544307     BX760055SS1
# 140      143      0  IceCat_Prod_28617831     B4527083AS1
# 141      144      0  IceCat_Prod_44544276     BFV30064SW1
#
#               category_id  category_label Product colour.1766  \
# 0    IceCat_Category_1837  Thermal Ribbon               Black
# 1    IceCat_Category_1837  Thermal Ribbon                Cyan
# 2    IceCat_Category_1837  Thermal Ribbon               Green
# ...

# %%
files_shape = [i.shape for i in files_df]

# %%
files_shape
# Out:
# [(14095, 1264),
#  (0, 1),
#  (0, 1),
#  (16, 174),
#  (142, 14),
#  (3, 38),
#  (27, 52),
#  (686, 134),
#  (625, 128),
#  (106, 52),
#  (0, 1),
#  (1, 40),
#  (1794, 236),
#  (14, 46),
#  (318, 248),
#  (144, 168),
#  (20, 80),
#  (34, 44),
#  (81, 208),
#  (11415, 234),
#  (0, 1),
#  (25, 38),
#  (20, 28),
#  (0, 1),
#  (420, 68),
#  (0, 1),
#  (0, 1),
#  (19, 46),
#  (137, 168),
#  (530, 226),
#  (6, 74),
#  (4737, 250),
#  (4, 12),
#  (59, 68),
#  (0, 1),
#  (12, 58),
#  (97, 208),
#  (370, 380),
#  (0, 1),
#  (778, 68),
#  (3, 10),
#  (246, 138),
#  (79, 280),
#  (0, 1),
#  (304, 86),
#  (487, 152),
#  (1931, 332),
#  (122, 124),
#  (2, 24),
#  (685, 540),
#  (1, 14),
#  (0, 1),
#  (0, 1),
#  (1176, 196),
#  (0, 1),
#  (156, 42),
#  (1, 34),
#  (10, 74),
#  (81, 50),
#  (14, 62),
#  (0, 1),
#  (1557, 326),
#  (473, 158),
#  (502, 92),
#  (18, 40),
#  (1, 14),
#  (1, 16),
#  (0, 1),
#  (8, 28),
#  (4933, 886),
#  (0, 1),
#  (55, 118),
#  (0, 1),
#  (1003, 684),
#  (0, 1),
# ...
